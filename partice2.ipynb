# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[10,20,30,40,50,60]
# line ---plot
plt.plot(x,y)
plt.show()

# %% [markdown]
# # pie chat

# %%
import matplotlib.pyplot as plt

x=[10,20,30]
ab=["monday","b","c"]
plt.pie(x,labels=ab)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[10,20,30,40,50,60]
data=[x]
# boxplot
plt.boxplot(data)


plt.show()

# %%
import matplotlib.pyplot as plt

x=[2,4,6,8]
y=[1,3,5,7]
c=["r","g","b","w"]
plt.bar(x,y)




plt.show()

# %%
set={1,2,3,5}

set.clear()
print(set)
# Out:
# set()

# %%
name1={
  "name":"vishal",
  "rollno":7.9,
  "marks":[98,88,77]
  }
print(name1)
# Out:
# {'name': 'vishal', 'rollno': 7.9, 'marks': [98, 88, 77]}
