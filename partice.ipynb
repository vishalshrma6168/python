# %%
from tkinter import *

def click(event):
    global scvalue
    Text=event.widget.cget("text") # widget--button btyega kon sa click hua hai,button se text dega
    if Text=="=":
        if scvalue.get().isdigit():
          value=int(scvalue.get())
           
        else:
            value=eval(scvalue.get())
            scvalue.set(value)
        screen.update()
        
    elif Text=="C":
        scvalue.set("")
        screen.update()   
    else:
        scvalue.set(scvalue.get() + Text)
        screen.update()


root=Tk()
root.title("Simple GUI")
root.geometry("644x600")

scvalue=StringVar()
scvalue.set("") 

# label
screen=Entry(root, textvar=scvalue, font="lucida 40 bold")
screen.pack(fill=X, pady=10, padx=10)

# frames for buttons
f1=Frame(root, bg="grey")

# buttons
b1=Button(f1,text="9",font="Lucidea 20 bold",padx=18,pady=20)
b1.pack(side=LEFT, padx=10, pady=10)
b1.bind("<Button-1>",click)

b1=Button(f1,text="8",font="Lucidea 20 bold",padx=18,pady=20)
b1.pack(side=LEFT, padx=10, pady=10)
b1.bind("<Button-1>",click)

b1=Button(f1,text="+",font="Lucidea 20 bold",padx=18,pady=20)
b1.pack(side=LEFT, padx=10, pady=10)
b1.bind("<Button-1>",click)

b1=Button(f1,text="=",font="Lucidea 20 bold",padx=18,pady=20)
b1.pack(side=LEFT, padx=10, pady=10)
b1.bind("<Button-1>",click)

b1=Button(f1,text="C",font="Lucidea 20 bold",padx=18,pady=20)
b1.pack(side=LEFT, padx=10, pady=10)
b1.bind("<Button-1>",click)

f1.pack()
root.mainloop()

# %%
from tkinter import *
def click(event):
  global scvalue
  text=event.widget.cget("text")
  if text=="=":
    if scvalue.get().isdigit():
      value = int(scvalue.get())
    else:
      value=eval(scvalue.get())
      scvalue.set(value)
      screen.update()
    
  elif text=="C":
    scvalue.set("")
    screen.update()
     
  else:
    scvalue.set(scvalue.get()+text)
    screen.update()
    

root =Tk()
root.title("cal")
root.geometry("644x900")

scvalue =StringVar()
scvalue.set("")

screen= Entry(root,textvar=scvalue,font="lucida 40 bold")
screen.pack(fill=X,padx=10,pady=10)

# frame
f1=Frame(root,bg="red")
b=Button(f1,text="9",padx=20,pady=18,font="lucida 20 bold")
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
b=Button(f1,text="8",padx=20,pady=18,font="lucida 20 bold")
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)

b=Button(f1,text="+",padx=20,pady=18,font="lucida 20 bold")
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
b=Button(f1,text="=",padx=20,pady=18,font="lucida 20 bold")
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
b=Button(f1,text="C",padx=20,pady=18,font="lucida 20 bold")
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)

f1.pack()
root.mainloop()

# %% [markdown]
# # tk

# %%
from tkinter import *
root=Tk()
# radio button
root.geometry("500x500")
# ab=IntVar()
# r1=Radiobutton(root,text="hello",variable=ab,bg="yellow",value=1).place(x=50,y=100)
# r2=Radiobutton(root,text="bye",variable=ab,bg="yellow",value=2).place(x=200,y=150)


# checkbutton
c1=Checkbutton(root,text="call",bg="yellow").place(x=200,y=100)
root.mainloop()

# %%
from tkinter import *

def click(event):
  global scavalue
  Text=event.widget.cget("text") # widget-----button access kon sa button click hua hai ,ans ciget---text show
  
  if Text=="=":
    if scavalue.get().isdigit():
      value=int(scavalue.get())
    else:
      value=eval(scavalue.get())# 2+2
      scavalue.set(value)
      screen.update()
  elif Text=="C":
    scavalue.set("")
    screen.update()
  else:
    scavalue.set(scavalue.get() + Text)
    screen.update()

root=Tk()
root.title("calculator")
root.geometry("500x500")

scavalue=StringVar()
scavalue.set("")
# input
screen=Entry(root,textvar=scavalue)
screen.pack(fill=X,padx=10,pady=10)

# frame
f1=Frame(root)
# b1
b=Button(f1,text="9",padx=20,pady=18)
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
# b1
b=Button(f1,text="8",padx=20,pady=18)
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
# b1
b=Button(f1,text="*",padx=20,pady=18)
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
# b1
b=Button(f1,text="=",padx=20,pady=18)
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
# b1
b=Button(f1,text="C",padx=20,pady=18)
b.pack(side=LEFT,padx=10,pady=10)
b.bind("<Button-1>",click)
f1.pack()
root.mainloop()

# %%
# seaborn ----advance version of matplotlib

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# line plot in seaborn
# without data frame
a=[1,2,3,4,5,6]
b=[1,4,5,7,8,9]
sns.lineplot(x=a,y=b)
plt.show()

# %%
# with data frame
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
a=[77,88,44,33,46]
b=[22,55,80,66,55]
x=pd.DataFrame({"data":a,"data2":b})
sns.lineplot(x=a,y=b,data=x)
plt.show()

# %%
# histogram plot
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=sns.load_dataset("penguins")
sns.displot(df["species"],kde=True)
